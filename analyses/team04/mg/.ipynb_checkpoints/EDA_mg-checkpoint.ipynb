# %% [markdown]
# # Setup

# %%
import numpy as np
import sklearn
import pandas as pd
import os
import zipfile

# %%
os.path.abspath('.')
# Out:
# 'C:\\Users\\Mike\\DataScienceProjects\\datahack2020\\datahack2020\\analyses\\team04\\mg'

# %%
# Set up some directory info, and figure export path
PROJECT_ROOT_DIR = '../../../'
NOTEBOOK_ID = 'EDA_mg'
FIGURE_EXPORT_PATH = os.path.join(PROJECT_ROOT_DIR, "analyses/team04/mg/figures", NOTEBOOK_ID)
os.makedirs(FIGURE_EXPORT_PATH, exist_ok = True)

# %%
# Define figure export
def save_fig(fig_id, tight_layout=True, fig_extension = "png", resolution = 300):
    path = os.path.join(FIGURE_EXPORT_PATH, fig_id + '.' + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format = fig_extension, dpi = resolution)

# %%
# Set up some plotting conveniences/settings
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Investigate Files
DATA_PATH = os.path.join(PROJECT_ROOT_DIR, "data/data.zip")
data = zipfile.ZipFile(DATA_PATH)    
# List all data files:
data.namelist()
# Out:
# ['data/',
#  'data/hf_samsha_providers.csv',
#  'data/pp_refill_events.csv',
#  'data/pp_sep_site_exchanges.csv',
#  'data/dph_od_resident_counts.csv',
#  'data/.DS_Store',
#  'data/hf_physician_locator.csv',
#  'data/dph_dash_ems_naloxone_zip.csv',
#  'data/pp_refill_zipcode_metrics.csv',
#  'data/dph_dash_n_ed_transfers.csv',
#  'data/dph_dash_ems_naloxone_sex.csv',
#  'data/pp_sep_site_participants.csv',
#  'data/dph_dash_n_naloxone_admins.csv',
#  'data/dph_od_incident_counts.csv',
#  'data/dph_dash_ems_naloxone_age.csv',
#  'data/hf_samsha_programs.csv']

# %%
# load data
hf_samsha_providers = pd.read_csv(data.open(r'data/hf_samsha_providers.csv', pwd = b"*$1Y5.2,|sG$"))
pp_refill_events = pd.read_csv(data.open(r'data/pp_refill_events.csv', pwd = b'*$1Y5.2,|sG$'))
pp_sep_site_exchanges = pd.read_csv(data.open(r'data/pp_sep_site_exchanges.csv', pwd = b'*$1Y5.2,|sG$'))
dph_od_resident_counts = pd.read_csv(data.open(r'data/dph_od_resident_counts.csv', pwd = b'*$1Y5.2,|sG$'))
pp_refill_zipcode_metrics = pd.read_csv(data.open(r'data/pp_refill_zipcode_metrics.csv', pwd = b'*$1Y5.2,|sG$'))
pp_sep_site_participants = pd.read_csv(data.open(r'data/pp_sep_site_participants.csv', pwd = b'*$1Y5.2,|sG$'))
hf_physician_locator = pd.read_csv(data.open(r'data/hf_physician_locator.csv', pwd = b'*$1Y5.2,|sG$'))

# %%
pp_refill_events.head(5)
# Out:
#     age gender   race  n_pp_refill  n_o_refill  n_ods  n_admins  n_revivals  \
# 0  42.0      m  white          1.0         0.0    5.0       6.0         6.0
# 1  33.0      m  white          8.0         0.0    2.0       1.0         1.0
# 2  32.0      m  white          2.0         1.0    NaN       NaN         NaN
# 3  36.0      m  white          1.0         0.0   10.0       1.0         1.0
# 4  38.0      f  white          2.0         0.0   10.0       0.0         0.0
#
#   used_narcan_type  ml_naloxone  ... od_drug_cocaine od_drug_fentanyl  \
# 0             nose          NaN  ...             0.0              1.0
# 1       injectable          NaN  ...             0.0              1.0
# 2             nose          NaN  ...             0.0              0.0
# 3             nose          NaN  ...             0.0              0.0
# 4             nose          0.0  ...             0.0              1.0
#
#    od_drug_unknown  od_drug_other        od_present  od_present_breath  \
# 0              0.0            0.0               bbp                0.0
# 1              0.0            0.0  all of the above                1.0
# 2              0.0            0.0               bbp                0.0
# 3              0.0            1.0               uou                0.0
# 4              0.0            0.0         pcnb, uou                1.0
#
#    od_present_unresponsive  od_present_coloring od_present_other  \
# 0                      0.0                  1.0              0.0
# 1                      1.0                  1.0              0.0
# 2                      0.0                  1.0              0.0
# 3                      1.0                  0.0              0.0
# 4                      1.0                  0.0              0.0
#
#    data_date_range
# 0       2018-q1-q2
# 1       2018-q1-q2
# 2       2018-q1-q2
# 3       2018-q1-q2
# 4       2018-q1-q2
#
# [5 rows x 30 columns]

# %%
pp_sep_site_exchanges.head(50)
# Out:
#     site_id visit_month  syringes_returned  syringes_dispensed  \
# 0       1.0  2019-01-01               5625                6175
# 1       1.0  2019-02-01              12700               13960
# 2       1.0  2019-03-01               8862               10470
# 3       1.0  2019-04-01               6130                7070
# 4       1.0  2019-05-01               9369                9830
# 5       1.0  2019-06-01              11550               11980
# 6       1.0  2019-08-01               9772               10290
# 7       1.0  2019-09-01               8673                8940
# 8       1.0  2019-10-01               9960               10690
# 9       1.0  2019-11-01               8287               11040
# 10      1.0  2019-12-01               6550                7710
# 11      2.0  2019-01-01               5106                5290
# 12      2.0  2019-02-01              10750               10820
# 13      2.0  2019-03-01               6210                6620
# 14      2.0  2019-04-01               5150                5150
# 15      2.0  2019-05-01               4445                5420
# 16      2.0  2019-06-01               4010                4190
# 17      2.0  2019-08-01               4360                4600
# 18      2.0  2019-09-01               4350                4610
# 19      2.0  2019-10-01               4475                5340
# 20      2.0  2019-11-01               4790                5750
# 21      2.0  2019-12-01               5150                5020
# 22      3.0  2019-01-01              12049               13800
# 23      3.0  2019-02-01               7550                7720
# 24      3.0  2019-03-01               9750               10761
# 25      3.0  2019-04-01               8311                9130
# 26      3.0  2019-05-01              13400               14180
# 27      3.0  2019-06-01               6370                6730
# 28      3.0  2019-08-01               7156                8330
# 29      3.0  2019-09-01               7160                8254
# 30      3.0  2019-10-01               8480                9260
# 31      3.0  2019-11-01               7715                9040
# 32      3.0  2019-12-01               4981                5570
# 33      4.0  2019-01-01              14490               16150
# 34      4.0  2019-02-01               6780                7010
# 35      4.0  2019-03-01               9295                9865
# 36      4.0  2019-04-01               5815                6580
# 37      4.0  2019-05-01               7636                8090
# 38      4.0  2019-06-01              10065               14030
# 39      4.0  2019-07-01                  0                 260
# 40      4.0  2019-08-01              10513               11066
# 41      4.0  2019-09-01              11230               11835
# 42      4.0  2019-10-01              11940               13410
# 43      4.0  2019-11-01              10790               13280
# 44      4.0  2019-12-01               4290                5330
# 45      5.0  2019-01-01             186500              199490
# 46      5.0  2019-02-01             169535              180570
# 47      5.0  2019-03-01             259530              265700
# 48      5.0  2019-04-01             204781              215975
# 49      5.0  2019-05-01             244030              256160
#
#     no_exchanging_for
# 0                  48
# 1                  89
# 2                  76
# 3                  64
# 4                  66
# 5                  81
# 6                  73
# 7                  62
# 8                  62
# 9                  85
# 10                 56
# 11                 41
# 12                 43
# 13                 40
# 14                 33
# 15                 36
# 16                 40
# 17                 32
# 18                 29
# 19                 47
# 20                 50
# 21                 34
# 22                117
# 23                102
# 24                120
# 25                 91
# 26                117
# 27                105
# 28                 89
# 29                 65
# 30                 56
# 31                 76
# 32                 44
# 33                 99
# 34                 41
# 35                 93
# 36                 66
# 37                 69
# 38                 58
# 39                 24
# 40                 72
# 41                 72
# 42                 70
# 43                 63
# 44                 30
# 45               1501
# 46               1444
# 47               1729
# 48               1257
# 49               1580

# %%
pp_refill_zipcode_metrics.head(5)
# Out:
#    participant_zip  avg_outcome_ems  avg_outcome_police  avg_outcome_ed  \
# 0          19111.0         0.366667            0.150000        0.200000
# 1          19120.0         0.318182            0.210526        0.052632
# 2          19122.0         0.187500            0.115385        0.000000
# 3          19124.0         0.358209            0.176471        0.125000
# 4          19125.0         0.206186            0.115942        0.072464
#
#    avg_outcome_death  avg_outcome_unk  avg_outcome_ok  avg_od_drug_heroin  \
# 0           0.000000         0.150000        0.700000            0.517241
# 1           0.000000         0.052632        0.526316            0.695652
# 2           0.000000         0.076923        0.769231            0.366667
# 3           0.026144         0.071895        0.581699            0.820513
# 4           0.043478         0.202899        0.608696            0.648352
#
#    avg_od_drug_cocaine  avg_od_drug_fentanyl  avg_od_drug_unknown  \
# 0             0.068966              0.310345             0.241379
# 1             0.130435              0.652174             0.000000
# 2             0.033333              0.366667             0.266667
# 3             0.200000              0.528205             0.061538
# 4             0.109890              0.494505             0.098901
#
#    avg_od_drug_other  avg_od_present_breath  avg_od_present_unresponsive  \
# 0           0.161290               0.642857                     0.750000
# 1           0.000000               0.304348                     0.565217
# 2           0.093750               0.387097                     0.419355
# 3           0.088235               0.438144                     0.541237
# 4           0.140000               0.377778                     0.511111
#
#    avg_od_present_coloring  avg_od_present_other  avg_cpr_used  n_observations
# 0                 0.678571              0.000000      0.600000              31
# 1                 0.478261              0.043478      0.428571              26
# 2                 0.322581              0.225806      0.333333              36
# 3                 0.556701              0.030928      0.453333             219
# 4                 0.555556              0.011236      0.419355             102

# %%
pp_sep_site_participants.head(5)
# Out:
#    site_id visit_month  count_distinct_participants
# 0        1  2019-01-01                           42
# 1        1  2019-10-01                           51
# 2        1  2019-11-01                           73
# 3        1  2019-12-01                           54
# 4        1  2019-02-01                           74

# %%
# According to https://www.phila.gov/media/20181002083054/Injecting_Drug_Users_Philadelphia_2015.pdf
# Approximately 55% of IDUs receive needles from needle exchanges.

# %% [markdown]
# ## Some quick plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

pp_sep_site_exchanges.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
from pandas.plotting import scatter_matrix

attributes = ["participant_zip", "avg_outcome_ems", "avg_outcome_police", "avg_outcome_ed", "avg_outcome_death", "avg_outcome_unk"]
scatter_matrix(pp_refill_zipcode_metrics[attributes], figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000223663F6E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366F210C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366F39848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223664A2248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223664D5C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366516E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022366548708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366580808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236658B408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223665C45C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236662AB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366662C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002236669BD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223666D2E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236670DF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236674B0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366785148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223667BA248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000223667F2348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236682B488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366863588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223668A3E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223668D5788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236690F888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022366946988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002236697FAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223669B8BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223669EFC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366A28D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366A60E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022366F69F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366FA70C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022366FE01C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223670182C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000223670503C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022367089508>]],
#       dtype=object)

# %%
pp_refill_zipcode_metrics.plot(kind = 'scatter', x ="avg_outcome_police", y = "avg_outcome_ems", alpha = .5)
