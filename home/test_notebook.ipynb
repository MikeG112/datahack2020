# %%
import os
import pandas as pd

from dotenv import load_dotenv
load_dotenv()

from urllib.parse import quote_plus
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql://{user}:{password}@45.79.16.246:30001/postgres"
        .format(
            user = os.environ["DATAHACK_DB_USER"],
            password = os.environ["DATAHACK_DB_PASS"]      
        )
    )
pd.read_sql_query("SELECT * FROM mtcars", engine)
# Out:
#      mpg  cyl   disp     hp  drat     wt   qsec   vs   am  gear  carb
# 0   21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0   4.0   4.0
# 1   21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0   4.0   4.0
# 2   22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0   4.0   1.0
# 3   21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0   3.0   1.0
# 4   18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0   3.0   2.0
# 5   18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0  0.0   3.0   1.0
# 6   14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0  0.0   3.0   4.0
# 7   24.4  4.0  146.7   62.0  3.69  3.190  20.00  1.0  0.0   4.0   2.0
# 8   22.8  4.0  140.8   95.0  3.92  3.150  22.90  1.0  0.0   4.0   2.0
# 9   19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0  0.0   4.0   4.0
# 10  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0  0.0   4.0   4.0
# 11  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0  0.0   3.0   3.0
# ...

# %%
print(engine.table_names())
# Out:
# ['mtcars', 'hf_samsha_providers', 'hf_samsha_programs', 'pp_sep_site_participants', 'pp_sep_site_exchanges', 'pct_indiv_acceptTransportHx_postNaloxone']

# %%
pp_sep_site_exchanges =pd.read_sql_query("SELECT * FROM pp_sep_site_exchanges", engine)

# %%
pp_sep_site_participants = pd.read_sql_query("SELECT * FROM pp_sep_site_participants", engine)
#hf_samsha_providers = pd.read_sql_query("SELECT * FROM hf_samsha_providers", engine)
#hf_samsha_programs = pd.read_sql_query("SELECT * FROM hf_samsha_programs", engine)
pct_indivaccept_TransportHx_postNaloxone = pd.read_sql_query("SELECT * FROM pct_indiv_acceptTransportHx_postNaloxone", engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\Miniconda3\envs\DataScienceEnvironment\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~\Miniconda3\envs\DataScienceEnvironment\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# UndefinedTable: relation "pct_indiv_accepttransporthx_postnaloxone" does not exist
# LINE 1: SELECT * FROM pct_indiv_acceptTransportHx_postNaloxone
#                       ^
#
#
# ...

# %%
pp_sep_site_exchanges.to_csv("pp_sep_site_exchanges.csv")

# %%
pp_sep_site_participants.to_csv("pp_sep_site_participants.csv")

# %%
pp_sep_site_exchanges.head(5)
# Out:
#    site_id visit_month  syringes_returned  syringes_dispensed  \
# 0      1.0  2019-01-01             5625.0              6175.0
# 1      1.0  2019-02-01            12700.0             13960.0
# 2      1.0  2019-03-01             8862.0             10470.0
# 3      1.0  2019-04-01             6130.0              7070.0
# 4      1.0  2019-05-01             9369.0              9830.0
#
#    no_exchanging_for
# 0               48.0
# 1               89.0
# 2               76.0
# 3               64.0
# 4               66.0

# %%
pp_sep_site_participants.head(5)
# Out:
#    site_id visit_month  count_distinct_participants
# 0      1.0  2019-01-01                         42.0
# 1      1.0  2019-10-01                         51.0
# 2      1.0  2019-11-01                         73.0
# 3      1.0  2019-12-01                         54.0
# 4      1.0  2019-02-01                         74.0

# %%
pp_sep_site_exchanges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 5 columns):
# site_id               141 non-null float64
# visit_month           142 non-null object
# syringes_returned     142 non-null float64
# syringes_dispensed    142 non-null float64
# no_exchanging_for     142 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 5.7+ KB
